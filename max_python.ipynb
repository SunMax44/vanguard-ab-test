# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# %matplotlib inline

# %%
path_1 = "https://raw.githubusercontent.com/data-bootcamp-v4/lessons/refs/heads/main/5_6_eda_inf_stats_tableau/project/files_for_project/df_final_demo.txt"
path_2 = "https://raw.githubusercontent.com/data-bootcamp-v4/lessons/refs/heads/main/5_6_eda_inf_stats_tableau/project/files_for_project/df_final_web_data_pt_1.txt"
path_3 = "https://raw.githubusercontent.com/data-bootcamp-v4/lessons/refs/heads/main/5_6_eda_inf_stats_tableau/project/files_for_project/df_final_web_data_pt_2.txt"
path_4 = "https://raw.githubusercontent.com/data-bootcamp-v4/lessons/refs/heads/main/5_6_eda_inf_stats_tableau/project/files_for_project/df_final_experiment_clients.txt"

# %%
df_final_demo = pd.read_csv(path_1)

# %%
df_final_demo[df_final_demo['client_id'] == 3155140]
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 29040    3155140             6.0              83.0      25.5     U        2.0
#
#             bal  calls_6_mnth  logons_6_mnth
# 29040  50003.83           5.0            8.0

# %%
df_final_demo[df_final_demo['client_id'] == 8633436]
# Out:
#       client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 5963    8633436             7.0              84.0      23.5     U        2.0
#
#            bal  calls_6_mnth  logons_6_mnth
# 5963  60895.72           5.0            8.0

# %%
df_final_demo[df_final_demo['client_id'] == 5901737]
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 16557    5901737            23.0             276.0      46.0     U        2.0
#
#             bal  calls_6_mnth  logons_6_mnth
# 16557  26882.09           0.0            3.0

# %%
df_final_demo[df_final_demo['client_id'] == 2859751]
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 27157    2859751            23.0             276.0      48.0     M        2.0
#
#             bal  calls_6_mnth  logons_6_mnth
# 27157  24682.51           1.0            4.0

# %%
df_final_demo[df_final_demo['client_id'] == 4473543	]
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 21757    4473543             5.0              70.0      40.5     U        3.0
#
#             bal  calls_6_mnth  logons_6_mnth
# 21757  66552.82           3.0            6.0

# %%
df_final_demo[df_final_demo['client_id'] == 461591]
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 31974     461591             5.0              70.0      39.5     U        2.0
#
#             bal  calls_6_mnth  logons_6_mnth
# 31974  37426.71           3.0            6.0

# %%
df_final_demo.describe().round(2)
# Out:
#         client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age  num_accts  \
# count    70609.00        70595.00          70595.00  70594.00   70595.00
# mean   5004991.88           12.05            150.66     46.44       2.26
# std    2877277.63            6.87             82.09     15.59       0.53
# min        169.00            2.00             33.00     13.50       1.00
# 25%    2519329.00            6.00             82.00     32.50       2.00
# 50%    5016978.00           11.00            136.00     47.00       2.00
# 75%    7483085.00           16.00            192.00     59.00       2.00
# max    9999839.00           62.00            749.00     96.00       8.00
#
#                bal  calls_6_mnth  logons_6_mnth
# count     70595.00      70595.00       70595.00
# mean     147445.24          3.38           5.57
# std      301508.71          2.24           2.35
# min       13789.42          0.00           1.00
# 25%       37346.84          1.00           4.00
# ...

# %%
df_final_demo['gendr'].value_counts()
# Out:
# gendr
# U    24122
# M    23724
# F    22746
# X        3
# Name: count, dtype: int64

# %%
def tukeys_test_inliers(data):
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    
    # Define bounds for the outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Identify the outliers
    inliers = data[(data > lower_bound) & (data < upper_bound)]
    
    return inliers

inliers = tukeys_test_inliers(df_final_demo['bal'])
inliers
inliers.mean() #-> first outlier is at index = 10
#df_cleaned = df.drop(outliers.index)
# Out:
# 78119.33428352268

# %%
df_final_demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70609 entries, 0 to 70608
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   client_id         70609 non-null  int64
#  1   clnt_tenure_yr    70595 non-null  float64
#  2   clnt_tenure_mnth  70595 non-null  float64
#  3   clnt_age          70594 non-null  float64
#  4   gendr             70595 non-null  object
#  5   num_accts         70595 non-null  float64
#  6   bal               70595 non-null  float64
#  7   calls_6_mnth      70595 non-null  float64
#  8   logons_6_mnth     70595 non-null  float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 4.8+ MB

# %%
important_cats = ['clnt_tenure_yr', 'clnt_tenure_mnth', 'clnt_age', 'bal', 'calls_6_mnth', 'logons_6_mnth']

iqr_mean_dict = {'mean':[], 'median':[], 'std': []}


for i in important_cats:
    inliers = tukeys_test_inliers(df_final_demo[i])
    iqr_mean_dict['mean'] += [round(inliers.mean(),2)]
    iqr_mean_dict['median'] += [round(inliers.median(),2)]
    iqr_mean_dict['std'] += [round(inliers.std(),2)]

iqr_mean_dict
iqr_mean_Joe = pd.DataFrame(iqr_mean_dict)
iqr_mean_Joe['index'] = important_cats
iqr_mean_Joe = iqr_mean_Joe.set_index('index')
iqr_mean_Joe
# Out:
#                       mean    median       std
# index
# clnt_tenure_yr       11.72     11.00      6.33
# clnt_tenure_mnth    145.38    132.00     73.89
# clnt_age             46.44     47.00     15.59
# bal               78119.33  55699.76  59622.11
# calls_6_mnth          3.38      3.00      2.24
# logons_6_mnth         5.57      5.00      2.35

# %%
df_final_demo['num_accts'].mean()
# Out:
# 2.2555280118988597

# %%
#df_final_demo['logons_6_mnth'].fillna(0, inplace=True)
#df_final_demo[df_final_demo['logons_6_mnth'] == 0]
#complete null rows delete preferrably
df_final_demo['logons_6_mnth'].dropna(inplace=True)
df_final_demo['logons_6_mnth'].value_counts()
# Out:
# logons_6_mnth
# 9.0    12350
# 3.0    10243
# 4.0    10220
# 7.0     9893
# 5.0     9254
# 6.0     7878
# 8.0     4810
# 2.0     3009
# 1.0     2938
# Name: count, dtype: int64

# %%
df_final_demo[df_final_demo['logons_6_mnth'] < 4].describe().round(2)
# Out:
#         client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age  num_accts  \
# count    16190.00        16190.00          16190.00  16190.00   16190.00
# mean   4985635.22           11.59            145.40     44.21       2.10
# std    2874681.17            6.40             76.33     14.70       0.34
# min        722.00            2.00             33.00     14.00       1.00
# 25%    2501028.75            6.00             82.00     32.00       2.00
# 50%    4968305.00           11.00            134.00     44.00       2.00
# 75%    7472399.75           15.00            187.00     55.50       2.00
# max    9999839.00           55.00            669.00     94.00       6.00
#
#                bal  calls_6_mnth  logons_6_mnth
# count     16190.00      16190.00       16190.00
# mean      88410.70          1.08           2.45
# std      181492.73          1.15           0.78
# min       13789.42          0.00           1.00
# 25%       29563.07          0.00           2.00
# ...

# %%
df_final_web_data_pt_1 = pd.read_csv(path_2)

# %%
df_final_web_data_pt_1
#check if client_id always has the same visitor_id:

# Group by 'client_id' and calculate the number of unique 'visitor_id' values
unique_visitor_counts = df_final_web_data_cc.groupby('client_id')['visitor_id'].nunique()

# Check if every 'client_id' has only 1 unique 'visitor_id'
consistent_mapping = unique_visitor_counts == 1

# Print any inconsistencies
if consistent_mapping.all():
    print("All client_ids always map to the same visitor_id.")
else:
    inconsistent_clients = unique_visitor_counts[unique_visitor_counts > 1]
    print("The following client_ids map to multiple visitor_ids:")
    print(inconsistent_clients)
#all of the 9773 mismatches
# Out:
# The following client_ids map to multiple visitor_ids:
# client_id
# 1643       2
# 1680       2
# 4653       2
# 6130       3
# 7367       2
#           ..
# 9996404    2
# 9996952    2
# 9997470    2
# 9998342    2
# 9999729    3
# Name: visitor_id, Length: 9773, dtype: int64

# %%
df_final_web_data_pt_2 = pd.read_csv(path_3)

# %%
#check if client_id always has the same visitor_id:

# Group by 'client_id' and calculate the number of unique 'visitor_id' values
unique_visitor_counts = df_final_web_data_pt_2.groupby('client_id')['visitor_id'].nunique()

# Check if every 'client_id' has only 1 unique 'visitor_id'
consistent_mapping = unique_visitor_counts == 1

# Print any inconsistencies
if consistent_mapping.all():
    print("All client_ids always map to the same visitor_id.")
else:
    inconsistent_clients = unique_visitor_counts[unique_visitor_counts > 1]
    print("The following client_ids map to multiple visitor_ids:")
    print(inconsistent_clients)

#only 3888 of the 9773 mismatches
# Out:
# The following client_ids map to multiple visitor_ids:
# client_id
# 4653       2
# 6130       3
# 7367       2
# 9282       2
# 11443      2
#           ..
# 9990101    2
# 9994607    2
# 9995309    2
# 9996088    2
# 9998342    2
# Name: visitor_id, Length: 3888, dtype: int64

# %%
df_final_web_data_cc = pd.concat([df_final_web_data_pt_1, df_final_web_data_pt_2], axis=0)
df_final_web_data_cc.to_csv('df_final_web_data_cc.csv', index=False)

# %%
df_final_experiment_clients = pd.read_csv(path_4)

# %%
df_final_experiment_clients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70609 entries, 0 to 70608
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   client_id  70609 non-null  int64
#  1   Variation  50500 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 1.1+ MB

# %%
df_final_web_data_cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 755405 entries, 0 to 412263
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   client_id     755405 non-null  int64
#  1   visitor_id    755405 non-null  object
#  2   visit_id      755405 non-null  object
#  3   process_step  755405 non-null  object
#  4   date_time     755405 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 34.6+ MB

# %%
df_final_web_data_cc[df_final_web_data_cc['client_id'] == 9988021]
# -> same visitor id (and same client) has two visit_ids for two different sessions/dates
# Out:
#      client_id            visitor_id                      visit_id  \
# 0      9988021  580560515_7732621733  781255054_21935453173_531117
# 1      9988021  580560515_7732621733  781255054_21935453173_531117
# 2      9988021  580560515_7732621733  781255054_21935453173_531117
# 3      9988021  580560515_7732621733  781255054_21935453173_531117
# 4      9988021  580560515_7732621733  781255054_21935453173_531117
# 5      9988021  580560515_7732621733  781255054_21935453173_531117
# 6      9988021  580560515_7732621733  781255054_21935453173_531117
# 7      9988021  580560515_7732621733  781255054_21935453173_531117
# 129    9988021  580560515_7732621733  219729223_42518459208_211914
# 130    9988021  580560515_7732621733  219729223_42518459208_211914
# 131    9988021  580560515_7732621733  219729223_42518459208_211914
# 132    9988021  580560515_7732621733  219729223_42518459208_211914
# 133    9988021  580560515_7732621733  219729223_42518459208_211914
# ...

# %%
df_final_web_data_cc[df_final_web_data_cc['client_id'] ==1680]
# Out:
#         client_id             visitor_id                      visit_id  \
# 226364       1680  262688118_24224945474  807102410_81976926205_767113
# 226365       1680  262688118_24224945474  807102410_81976926205_767113
# 271295       1680   95496252_89175705853  561970892_34952005684_284982
# 271296       1680   95496252_89175705853  561970892_34952005684_284982
# 271297       1680   95496252_89175705853  561970892_34952005684_284982
# 271298       1680   95496252_89175705853  561970892_34952005684_284982
# 271299       1680   95496252_89175705853  561970892_34952005684_284982
#
#        process_step            date_time
# 226364        start  2017-03-15 09:57:38
# 226365        start  2017-03-15 09:57:21
# 271295      confirm  2017-06-09 07:45:58
# 271296       step_3  2017-06-09 07:44:35
# 271297       step_2  2017-06-09 07:43:23
# 271298       step_1  2017-06-09 07:43:04
# 271299        start  2017-06-09 07:42:33

# %%
#check if client_id always has the same visitor_id:

# Group by 'client_id' and calculate the number of unique 'visitor_id' values
unique_visitor_counts = df_final_web_data_cc.groupby('client_id')['visitor_id'].nunique()

# Check if every 'client_id' has only 1 unique 'visitor_id'
consistent_mapping = unique_visitor_counts == 1

# Print any inconsistencies
if consistent_mapping.all():
    print("All client_ids always map to the same visitor_id.")
else:
    inconsistent_clients = unique_visitor_counts[unique_visitor_counts > 1]
    print("The following client_ids map to multiple visitor_ids:")
    print(inconsistent_clients)
# Out:
# The following client_ids map to multiple visitor_ids:
# client_id
# 1643       2
# 1680       2
# 4653       2
# 6130       3
# 7367       2
#           ..
# 9996404    2
# 9996952    2
# 9997470    2
# 9998342    2
# 9999729    3
# Name: visitor_id, Length: 9773, dtype: int64

# %%
#calculate completion rate based on visit_id
list(df_final_web_data_cc.groupby('visit_id'))
#158095 visits
# Out:
# [('100012776_37918976071_457913',
#           client_id            visitor_id                      visit_id  \
#   108613    3561384  451664975_1722933822  100012776_37918976071_457913
#   108614    3561384  451664975_1722933822  100012776_37918976071_457913
#
#          process_step            date_time
#   108613      confirm  2017-04-26 13:23:09
#   108614      confirm  2017-04-26 13:22:17  ),
#  ('1000165_4190026492_760066',
#           client_id             visitor_id                   visit_id  \
#   104806    9056452  306992881_89423906595  1000165_4190026492_760066
#   104807    9056452  306992881_89423906595  1000165_4190026492_760066
#   104808    9056452  306992881_89423906595  1000165_4190026492_760066
#   104809    9056452  306992881_89423906595  1000165_4190026492_760066
#   104810    9056452  306992881_89423906595  1000165_4190026492_760066
#
#          process_step            date_time
#   104806      confirm  2017-06-04 01:09:50
# ...

# %%
#calculate completion rate based on visit_id
visits_grouped = df_final_web_data_cc.groupby('visit_id')
total_visits = len(visits_grouped)
df_success_visits = visits_grouped.filter(lambda x: (x['process_step'] == 'confirm').any())
n_success_visits = df_success_visits['visit_id'].nunique()
completion_rate_overall = n_success_visits / total_visits

#df_final_web_data_cc['complet_rate'] = visits_grouped.filter(lambda x: (x['status'] == 'yes').any() / len(visits_grouped)
# Out:
# 0.5681773617128941

# %%
df_final_web_data_cc[df_final_web_data_cc['process_step'] == 'confirm'].any()
# Out:
# client_id       True
# visitor_id      True
# visit_id        True
# process_step    True
# date_time       True
# dtype: bool

# %%
# Out:
#   group  value status
# 0     A     10    yes
# 1     A     15     no
# 2     B     10    yes
# 3     B     20     no
# 4     C      5    yes
# 5     C      5    yes
# 6     C     15     no
